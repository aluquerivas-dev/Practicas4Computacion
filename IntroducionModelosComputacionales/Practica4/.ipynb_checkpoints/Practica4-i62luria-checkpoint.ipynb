# %% [markdown]
# <img src="./img/e_preg1.png" />

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import svm

# Cargar el dataset
data = pd.read_csv('./BasesDatos/csv/dataset1.csv',header=None)
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# Entrenar el modelo SVM
svm_model = svm.SVC(kernel='linear',C=200)
svm_model.fit(X, y)

# Representar los puntos
plt.figure(1)
plt.clf()
plt.scatter(X[:, 0], X[:, 1], c=y, zorder=10, cmap=plt.cm.Paired)

# Representar el hiperplano separador
plt.axis('tight')
# Extraer límites
x_min = X[:, 0].min()
x_max = X[:, 0].max()
y_min = X[:, 1].min()
y_max = X[:, 1].max()

# Crear un grid con todos los puntos y obtener el valor Z devuelto por la SVM
XX, YY = np.mgrid[x_min:x_max:500j, y_min:y_max:500j]
Z = svm_model.decision_function(np.c_[XX.ravel(), YY.ravel()])

# Hacer un plot a color con los resultados
Z = Z.reshape(XX.shape)
plt.pcolormesh(XX, YY, Z > 0)
plt.contour(XX, YY, Z, colors=['k', 'k', 'k'], linestyles=['--', '-', '--'],
                levels=[-.5, 0, .5])

plt.show()

# %% [markdown]
# ###  Respuesta [1]:
#     Podemos ver un Script de Python donde se han importado las diferentes librerias para poder usar el modelo de SVM, en este caso se ha usado el dataset1.csv y se ha especificado que no se utilice cabecera. Los parametros de entranmiento son el Kernel usado es el LINEAL y se ha usado un valor de penalty de 200 Unidades. La X es las entradas del dataset y la Y es la salida, el metodo fit lo que hace es ejecutar el entrenamiento del modelo con las entradas y salidas , luego de eso se hacen una seria de trasformaciones en los datos de salida para poder ver su representación grafica mediante matplotlib.

# %% [markdown]
# <img src="./img/e_preg2.png" />

# %% [markdown]
# ###  Respuesta [2]:
# El mejor hiperplano separador para separar los patrones sería un hiperplano recto que corte en dos segmentos
# bien diferenciados

# %% [markdown]
# <img src="./img/e_preg3.png" />

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import svm

# Cargar el dataset
data = pd.read_csv('./BasesDatos/csv/dataset1.csv',header=None)
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

for Penalty in [0.01,0.1,1,10,100,200,1000,10000]:
    # Entrenar el modelo SVM
    svm_model = svm.SVC(kernel='linear',C=Penalty )
    svm_model.fit(X, y)

    # Representar los puntos
    plt.figure(1)
    plt.clf()
    plt.scatter(X[:, 0], X[:, 1], c=y, zorder=10, cmap=plt.cm.Paired)

    # Representar el hiperplano separador
    plt.axis('tight')
    # Extraer límites
    x_min = X[:, 0].min()
    x_max = X[:, 0].max()
    y_min = X[:, 1].min()
    y_max = X[:, 1].max()

    # Crear un grid con todos los puntos y obtener el valor Z devuelto por la SVM
    XX, YY = np.mgrid[x_min:x_max:500j, y_min:y_max:500j]
    Z = svm_model.decision_function(np.c_[XX.ravel(), YY.ravel()])

    # Hacer un plot a color con los resultados
    Z = Z.reshape(XX.shape)
    plt.pcolormesh(XX, YY, Z > 0)
    plt.contour(XX, YY, Z, colors=['k', 'k', 'k'], linestyles=['--', '-', '--'],
                    levels=[-.5, 0, .5])
    print('Valor de Penalty usado:'+str(Penalty))
    plt.show()
# Out:
# c:\users\aluqu\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:38: UserWarning: No contour levels were found within the data range.
# Valor de Penalty usado:0.01
# Valor de Penalty usado:0.1
# Valor de Penalty usado:1
# Valor de Penalty usado:10
# Valor de Penalty usado:100
# Valor de Penalty usado:200
# Valor de Penalty usado:1000
# Valor de Penalty usado:10000

# %% [markdown]
# ###  Respuesta [3]:
# Se observa que variando el valor de **Penalty** el ajuste en los primeros valores es malo, es observable que a mayor valor de **Penalty** el modelo comete menos fallos pero se observa que a partir de cierto valor de **Penalty** el modelo esta sobre entrenando, yo personalmente me quedaría con el valor por defecto dado en la practica que es un **Penalty de 200 unidades** o muy cercano a este valor.

# %% [markdown]
# <img src="./img/e_preg4.png" />

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import svm

# Cargar el dataset
data = pd.read_csv('./BasesDatos/csv/dataset2.csv',header=None)
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

for Penalty in [0.01,0.1,1,10,100,200,1000,10000]:
    # Entrenar el modelo SVM
    svm_model = svm.SVC(kernel='linear',C=Penalty )
    svm_model.fit(X, y)

    # Representar los puntos
    plt.figure(1)
    plt.clf()
    plt.scatter(X[:, 0], X[:, 1], c=y, zorder=10, cmap=plt.cm.Paired)

    # Representar el hiperplano separador
    plt.axis('tight')
    # Extraer límites
    x_min = X[:, 0].min()
    x_max = X[:, 0].max()
    y_min = X[:, 1].min()
    y_max = X[:, 1].max()

    # Crear un grid con todos los puntos y obtener el valor Z devuelto por la SVM
    XX, YY = np.mgrid[x_min:x_max:500j, y_min:y_max:500j]
    Z = svm_model.decision_function(np.c_[XX.ravel(), YY.ravel()])

    # Hacer un plot a color con los resultados
    Z = Z.reshape(XX.shape)
    plt.pcolormesh(XX, YY, Z > 0)
    plt.contour(XX, YY, Z, colors=['k', 'k', 'k'], linestyles=['--', '-', '--'],
                    levels=[-.5, 0, .5])
    print('Valor de Penalty usado:'+str(Penalty))
    plt.show()
# Out:
# c:\users\aluqu\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:38: UserWarning: No contour levels were found within the data range.
# Valor de Penalty usado:0.01
# c:\users\aluqu\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:38: UserWarning: No contour levels were found within the data range.
# Valor de Penalty usado:0.1
# c:\users\aluqu\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:38: UserWarning: No contour levels were found within the data range.
# Valor de Penalty usado:1
# c:\users\aluqu\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:38: UserWarning: No contour levels were found within the data range.
# Valor de Penalty usado:10
# c:\users\aluqu\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:38: UserWarning: No contour levels were found within the data range.
# Valor de Penalty usado:100
# ...

# %% [markdown]
# ###  Respuesta [4]:
# En este dataset es imposible hacer una separación de las clases mediante un hiperplano lineal, puede que usando una transformación del espacio si sea posible pero tal y comom estan los patrones da igual que valor metamos de **Penalty** que es absurdo usar un **Kernel** lineal, yo usaria un **Kernel** RBF.

# %% [markdown]
# <img src="./img/e_preg5.png" />

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import svm

# Cargar el dataset
data = pd.read_csv('./BasesDatos/csv/dataset2.csv',header=None)
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values


# Entrenar el modelo SVM
svm_model = svm.SVC(kernel='rbf',C=10,gamma=400)
svm_model.fit(X, y)

# Representar los puntos
plt.figure(1)
plt.clf()
plt.scatter(X[:, 0], X[:, 1], c=y, zorder=10, cmap=plt.cm.Paired)

# Representar el hiperplano separador
plt.axis('tight')
    # Extraer límites
x_min = X[:, 0].min()
x_max = X[:, 0].max()
y_min = X[:, 1].min()
y_max = X[:, 1].max()

# Crear un grid con todos los puntos y obtener el valor Z devuelto por la SVM
XX, YY = np.mgrid[x_min:x_max:500j, y_min:y_max:500j]
Z = svm_model.decision_function(np.c_[XX.ravel(), YY.ravel()])

# Hacer un plot a color con los resultados
Z = Z.reshape(XX.shape)
plt.pcolormesh(XX, YY, Z > 0)
plt.contour(XX, YY, Z, colors=['k', 'k', 'k'], linestyles=['--', '-', '--'],
                    levels=[-.5, 0, .5])
plt.show()

# %% [markdown]
# ###  Respuesta [5]:
# Los valores considerados para **C** han sido [10,25,100,250,500], y para **Gamma** han sido [10,50,100,200,400,1000] en las distintas pruebas se puede observar que si por ejemplo usamos una **C** baja y una **Gamma** baja por ejemplo 10 y 10, el modelo se ve claramente que esta en infra-entrenamiento, mientras que si tocamos las pruebas con los valores de 500 y 1000 se produce un sobre-entrenamiento ,la configuración que mejor se ajusta al modelo desde mi punto de vista es la de un valor de **C=10** y **Ganmma=400**.

# %% [markdown]
# <img src="./img/e_preg6.png" />

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import svm

# Cargar el dataset
data = pd.read_csv('./BasesDatos/csv/dataset3.csv',header=None)
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values


# Entrenar el modelo SVM
svm_model = svm.SVC(kernel='rbf',C=10,gamma=400)
svm_model.fit(X, y)

# Representar los puntos
plt.figure(1)
plt.clf()
plt.scatter(X[:, 0], X[:, 1], c=y, zorder=10, cmap=plt.cm.Paired)

# Representar el hiperplano separador
plt.axis('tight')
    # Extraer límites
x_min = X[:, 0].min()
x_max = X[:, 0].max()
y_min = X[:, 1].min()
y_max = X[:, 1].max()

# Crear un grid con todos los puntos y obtener el valor Z devuelto por la SVM
XX, YY = np.mgrid[x_min:x_max:500j, y_min:y_max:500j]


# Hacer un plot a color con los resultados


plt.contour(XX, YY, colors=['k', 'k'], linestyles=['--', '-'],
                    levels=[-.5, 0])
plt.show()
# Out:
# c:\users\aluqu\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:38: UserWarning: No contour levels were found within the data range.

# %% [markdown]
# ###  Respuesta [6]:
# En este dataset es imposible hacer una separación de las clases mediante un hiperplano lineal, puede que usando una transformación del espacio si sea posible , en tal caso yo usaria un **Kernel** RBF para el ajuste del modelo.
# En cuanto a los valores aoutliers se puede observar que algunos puntos de la clase naranja estan en donde estan los de la clase azul, son pocos pero se consideran valores outliers.

# %% [markdown]
# <img src="./img/e_preg7.png" />

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import svm

# Cargar el dataset
data = pd.read_csv('./BasesDatos/csv/dataset3.csv',header=None)
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

for Penalty in [0.02,0.2,2,200]:
    for Gamma in [0.02,0.2,2,200]:
        # Entrenar el modelo SVM
        svm_model = svm.SVC(kernel='rbf',C=Penalty,gamma=Gamma)
        svm_model.fit(X, y)

        # Representar los puntos
        plt.figure(1)
        plt.clf()
        plt.scatter(X[:, 0], X[:, 1], c=y, zorder=10, cmap=plt.cm.Paired)

        # Representar el hiperplano separador
        plt.axis('tight')
        # Extraer límites
        x_min = X[:, 0].min()
        x_max = X[:, 0].max()
        y_min = X[:, 1].min()
        y_max = X[:, 1].max()

        # Crear un grid con todos los puntos y obtener el valor Z devuelto por la SVM
        XX, YY = np.mgrid[x_min:x_max:500j, y_min:y_max:500j]
        Z = svm_model.decision_function(np.c_[XX.ravel(), YY.ravel()])

        # Hacer un plot a color con los resultados
        Z = Z.reshape(XX.shape)
        plt.pcolormesh(XX, YY, Z > 0)
        plt.contour(XX, YY, Z, colors=['k', 'k', 'k'], linestyles=['--', '-', '--'],
                        levels=[-.5, 0, .5])
        print('Valor de Penalty usado:'+str(Penalty))
        print('Valor de Gamma usado:'+str(Gamma))
        plt.show()
# Out:
# Valor de Penalty usado:0.02
# Valor de Gamma usado:0.02
# Valor de Penalty usado:0.02
# Valor de Gamma usado:0.2
# Valor de Penalty usado:0.02
# Valor de Gamma usado:2
# Valor de Penalty usado:0.02
# Valor de Gamma usado:200
# Valor de Penalty usado:0.2
# Valor de Gamma usado:0.02
# Valor de Penalty usado:0.2
# Valor de Gamma usado:0.2
# Valor de Penalty usado:0.2
# Valor de Gamma usado:2
# Valor de Penalty usado:0.2
# Valor de Gamma usado:200
# Valor de Penalty usado:2
# Valor de Gamma usado:0.02
# Valor de Penalty usado:2
# Valor de Gamma usado:0.2
# Valor de Penalty usado:2
# Valor de Gamma usado:2
# Valor de Penalty usado:2
# Valor de Gamma usado:200
# Valor de Penalty usado:200
# Valor de Gamma usado:0.02
# Valor de Penalty usado:200
# Valor de Gamma usado:0.2
# Valor de Penalty usado:200
# Valor de Gamma usado:2
# Valor de Penalty usado:200
# Valor de Gamma usado:200

# %% [markdown]
# ###  Respuesta [7]:
# Se observa que las pruebas donde **Gamma** y **Penalty** directamente hay configuraciones que no funcionan bien o en las que funciona un poco dando señales de que hay un infra-entrenamiento, con valores de **Gamma=200** y **Penalty=200** claramente hay un sobre-entrenamiento del modelo pues hasta los valores outliers son detectados.
#
# Para mi los parametros optimos de la lista probada son **Gamma=200** y **Penalty=2**.

# %% [markdown]
# <img src="./img/e_preg8.png" />

# %%
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit

data = pd.read_csv('./BasesDatos/csv/dataset3.csv',header=None)

inputs = data.iloc[:,:-1].values
outputs = data.iloc[:,-1].values

SSS = StratifiedShuffleSplit(n_splits=20, test_size=0.25,train_size=0.75)
#En SSS.split guardamos todos los split aleatorios del dataset, usamos un for para si fuera de mas de 1 split.
SPLIT = 1
for train_index, test_index in SSS.split(inputs, outputs):
    X_train, X_test = inputs[train_index], inputs[test_index]
    Y_train, Y_test = outputs[train_index], outputs[test_index]

    svm_model = svm.SVC(kernel='rbf', C=0.2, gamma=200)
    svm_model.fit(X_train,Y_train)
    Y_pred = svm_model.predict(X_test)

    print('Split Numero: '+str(SPLIT)+' --> '+str(accuracy_score(Y_test,Y_pred)))
    SPLIT=SPLIT+1
# Out:
# Split Numero: 1 --> 0.7956989247311828
# Split Numero: 2 --> 0.8602150537634409
# Split Numero: 3 --> 0.8602150537634409
# Split Numero: 4 --> 0.8924731182795699
# Split Numero: 5 --> 0.8602150537634409
# Split Numero: 6 --> 0.8387096774193549
# Split Numero: 7 --> 0.8817204301075269
# Split Numero: 8 --> 0.7956989247311828
# Split Numero: 9 --> 0.9247311827956989
# Split Numero: 10 --> 0.8709677419354839
# Split Numero: 11 --> 0.8602150537634409
# Split Numero: 12 --> 0.8387096774193549
# Split Numero: 13 --> 0.8279569892473119
# Split Numero: 14 --> 0.8172043010752689
# Split Numero: 15 --> 0.8494623655913979
# Split Numero: 16 --> 0.8387096774193549
# Split Numero: 17 --> 0.8602150537634409
# Split Numero: 18 --> 0.8279569892473119
# Split Numero: 19 --> 0.7419354838709677
# Split Numero: 20 --> 0.7956989247311828

# %% [markdown]
# ###  Respuesta [8]:
# Como se observa a la hora de realizar una clasificación, el **accuracy_score** dependera de la semilla inicializada por el método **StratifiedShuffleSplit** , cosa que es evidente a la hora de realizar este método.

# %% [markdown]
# <img src="./img/e_preg9.png" />

# %%
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV
from sklearn.svm import SVC

tuned_parameters = [{
                    'kernel': ['rbf'],
                    'gamma': np.logspace(-15, 3, num=9, base=2),
                     'C': np.logspace(-5, 15, num=11, base=2)
                    }]
optimo = GridSearchCV(estimator=svm.SVC(kernel='rbf'),param_grid=tuned_parameters, n_jobs=-1, cv=5)


data = pd.read_csv('./BasesDatos/csv/dataset3.csv',header=None)

inputs = data.iloc[:,:-1].values
outputs = data.iloc[:,-1].values

SSS = StratifiedShuffleSplit(n_splits=10, test_size=0.25,train_size=0.75)
#En SSS.split guardamos todos los split aleatorios del dataset, usamos un for para si fuera de mas de 1 split.
SPLIT = 1
C_ARRAY = []
G_ARRAY = []
for train_index, test_index in SSS.split(inputs, outputs):
    X_train, X_test = inputs[train_index], inputs[test_index]
    Y_train, Y_test = outputs[train_index], outputs[test_index]

    optimo.fit(X_train, Y_train)
    Y_pred = optimo.predict(X_test)
    print('Valor de C: '+str(optimo.best_params_['C']))
    print('Valor de GAMMA: '+str(optimo.best_params_['gamma']))
    print('Valor de score: '+str(accuracy_score(Y_test, Y_pred)))
    C_ARRAY.append(optimo.best_params_['C'])
    G_ARRAY.append(optimo.best_params_['gamma'])

print("Parametro 'C' estimado medio: "+str(np.mean(C_ARRAY)))
print("Parametro 'gamma' estimado medio: "+str(np.mean(G_ARRAY)))
# Out:
# c:\users\aluqu\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Valor de C: 512.0
# Valor de GAMMA: 8.0
# Valor de score: 0.9139784946236559
# c:\users\aluqu\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Valor de C: 128.0
# Valor de GAMMA: 1.681792830507429
# Valor de score: 0.8602150537634409
# ...

# %% [markdown]
# ###  Respuesta [9]:
# Se ha usado el método **GridSearchCV** que permite estimar los mejores parametros para un modelo, en nuestro caso hemos querido estimar los mejores parametros de **C** y **gamma** , hemos usado 10 split de **75%** y **25%** en train y test respectivamente para tener diversidad de patrones aleatorios, la estimación de los parametros  **C** y **gamma** tienen un cambio abrupto en algunas lanzadas y esto es devido a la aleatoriedad producida por el split de **train** y **test**.

# %% [markdown]
# <img src="./img/e_preg10.png" />

# %% [markdown]
# ###  Respuesta [10]:
# Basicamente que a mano tienes miles de combinaciones a realizar, el uso de **GridSearchCV** no deja de ser un método donde le pasas una lista de parametros que tu consideres oportunos y el internamente comprueba que tan buenos son estos parámetros.
# Lo que este método te puede sacar en un tiempo relativamente corto,nosotros podríamos estar estimando los valores de manera manual días. Támbien podemos caer en sobre-entrenamiento del modelo al estimar lo que para nosotros serían unos buenos parámetros de manera manual, el método **GridSearchCV** ya lo hace por nosotros.

# %% [markdown]
# <img src="./img/e_preg11.png" />

# %%
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
'-----------------------------------------------'
VALORES = {
    'C': np.logspace(-5, 15, num=11, base=2),
    'kernel': ['rbf'],
    'gamma': np.logspace(-15, 3, num=9, base=2)
}
'''
OPCIONES=[]
for C in VALORES['C']:
    for KERNEL in VALORES['kernel']:
        for GAMMA in VALORES['gamma']:
            OPCIONES.append((C,KERNEL,GAMMA))
'''
OPCIONES = [(C,KERNEL,GAMMA) for C in VALORES['C'] for KERNEL in VALORES['kernel'] for GAMMA in VALORES['gamma']]

data = pd.read_csv('./BasesDatos/csv/dataset3.csv',header=None)

inputs = data.iloc[:,:-1].values
outputs = data.iloc[:,-1].values

SKF = StratifiedKFold(n_splits=5)
print(SKF)
#En SKFsplit guardamos todos los K-FOLD del dataset, usamos un for para si fuera de mas de 1 split.
RESULTADO =\
            {
            'C': 0,
            'kernel': ['rbf'],
            'gamma': 0,
            'score': 0
            }
MAX = 0
for train_index, test_index in SKF.split(inputs, outputs):
    X_train, X_test = inputs[train_index], inputs[test_index]
    Y_train, Y_test = outputs[train_index], outputs[test_index]
    for (C, KERNEL, GAMMA) in OPCIONES:
        svm_model = svm.SVC(kernel=KERNEL, C=C, gamma=GAMMA)
        svm_model.fit(X_train,Y_train)
        Y_pred = svm_model.predict(X_test)

        print(accuracy_score(Y_test, Y_pred))
        if accuracy_score(Y_test, Y_pred) > MAX:
            MAX = accuracy_score(Y_test, Y_pred)
            RESULTADO['C'] = C
            RESULTADO['gamma'] = GAMMA
            RESULTADO['score'] = accuracy_score(Y_test,Y_pred)

print(RESULTADO)
# Out:
# StratifiedKFold(n_splits=5, random_state=None, shuffle=False)
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.43243243243243246
# 0.5135135135135135
# 0.5675675675675675
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.4594594594594595
# 0.40540540540540543
# 0.5135135135135135
# 0.6891891891891891
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5
# 0.40540540540540543
# 0.44594594594594594
# 0.6891891891891891
# 0.7027027027027027
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.5135135135135135
# 0.40540540540540543
# 0.4189189189189189
# 0.5135135135135135
# 0.6756756756756757
# 0.6891891891891891
# ...

# %% [markdown]
# ###  Respuesta [11]:
# Los valores que me han salido son semejantes a los resultantes en **GridSearchCV** , **{'C': 2.0, 'kernel': ['rbf'], 'gamma': 0.3535533905932738, 'score': 1.0}**, hay que tener en cuenta como esta implementado  **GridSearchCV** , pues para estimar los mejores parametros solo hemos tenido en cuenta que el **accuracy_score(Y_test,Y_pred)** sea mas alto, con lo que en muchos casos esto llevas a un sobre-entrenamiento del modelo.

# %% [markdown]
# <img src="./img/e_preg12.png" />

# %%
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV
from sklearn.svm import SVC

tuned_parameters = [{
                    'kernel': ['rbf'],
                    'gamma': np.logspace(-15, 3, num=9, base=2),
                     'C': np.logspace(-5, 15, num=11, base=2)
                    }]


optimo = GridSearchCV(estimator=svm.SVC(kernel='rbf'),param_grid=tuned_parameters, n_jobs=-1, cv=5)
data_train = pd.read_csv('./BasesDatos/csv/train_nomnist.csv',header=None)
data_test = pd.read_csv('./BasesDatos/csv/test_nomnist.csv',header=None)

train_inputs = data_train.iloc[:,:-1].values
train_outputs = data_train.iloc[:,-1].values

test_inputs = data_test.iloc[:,:-1].values
test_outputs = data_test.iloc[:,-1].values

C_ARRAY = []
G_ARRAY = []

optimo.fit(train_inputs, train_outputs)
Y_pred = optimo.predict(test_inputs)
print('Valor de C: '+str(optimo.best_params_['C']))
print('Valor de GAMMA: '+str(optimo.best_params_['gamma']))
print('Valor de score: '+str(accuracy_score(test_outputs, Y_pred)))
C_ARRAY.append(optimo.best_params_['C'])
G_ARRAY.append(optimo.best_params_['gamma'])

print("Parametro 'C' estimado medio: "+str(np.mean(C_ARRAY)))
print("Parametro 'gamma' estimado medio: "+str(np.mean(G_ARRAY)))

# %% [markdown]
# ###  Respuesta [12]:
#
# Para esta prueba he utilizado el mismo vector de parámetros de C y gamma que para el ejercicio anterior, y aunque para esta base de datos el proceso tarda mas por el número de patrones y su tamaño y sobre todo por el uso de **GridSearchCV** que se encarga de encontrar los valores óptimos.
#
# El valor que se pide comparar contra las practicas anteriores no tiene mucho sentido puesto que son diferentes base de datos, es cierto que los valores de **accuracy_score** son semejantes. En el SCRIPT del ejercicio 9 se utilizaba el uso de **StratifiedShuffleSplit**, en este ejercicio lo hemos eliminado puesto que la base de datos de NOMNIST ya incluye ficheros de **train** y **test**.Los mejores valores han sido:
#     <ol style="font-weight: bold;margin-left:15%;">
#         <li>Valor de C: 8.0</li>
#         <li>Valor de GAMMA: 0.0001451668841556056</li>
#         <li>Valor de score: 0.91</li>
#     </ol>

# %% [markdown]
# <img src="./img/e_preg13.png" />

# %%
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV
from sklearn.svm import SVC
import time
tuned_parameters = [{
                    'kernel': ['rbf'],
                    'gamma': np.logspace(-15, 3, num=9, base=2),
                     'C': np.logspace(-5, 15, num=11, base=2)
                    }]

for CV in [3,5,10]:
    time_start = time.perf_counter()
    optimo = GridSearchCV(estimator=svm.SVC(kernel='rbf'),param_grid=tuned_parameters, n_jobs=-1, cv=CV)
    data_train = pd.read_csv('./BasesDatos/csv/train_nomnist.csv',header=None)
    data_test = pd.read_csv('./BasesDatos/csv/test_nomnist.csv',header=None)

    train_inputs = data_train.iloc[:,:-1].values
    train_outputs = data_train.iloc[:,-1].values

    test_inputs = data_test.iloc[:,:-1].values
    test_outputs = data_test.iloc[:,-1].values

    optimo.fit(train_inputs, train_outputs)
    Y_pred = optimo.predict(test_inputs)
    time_elapsed = (time.perf_counter() - time_start)
    print("%5.1f segundos" % (time_elapsed))

    print('Valor de K: ' + str(CV))
    print('Valor de C: '+str(optimo.best_params_['C']))
    print('Valor de GAMMA: '+str(optimo.best_params_['gamma']))
    print('Valor de score: '+str(accuracy_score(test_outputs, Y_pred)))

# %% [markdown]
# ###  Respuesta [13]:
# El párametro **CV** de **GridSearchCV** viene de las siglas Cross-Validation, los valores de **C** y **gamma** son:
#     <ol style="font-weight: bold;margin-left:15%;">
#         <li>gamma': np.logspace(-15, 3, num=9, base=2)</li>
#         <li>'C': np.logspace(-5, 15, num=11, base=2)</li>
#     </ol>
#
# El Script tarda tanto en calcular la salida porque el método **GridSearchCV** tiene un rago de valores de **C** y **gamma** muy amplio, si este rango de valores se disminuyera por seguro que el método tárdaria menos y tambíen debemos de tener en cuenta el valor de **K** que recive la función de **GridSearchCV**, en la siguiente tabla se muestra un estudio comparativo variando el valor de **K**:
#
# <table style="border-collapse:collapse;border-spacing:0" class="tg"><tr><th style="font-family:Arial, sans-serif;font-size:14px;font-weight:normal;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;text-align:left;vertical-align:top"></th><th style="font-family:Arial, sans-serif;font-size:14px;font-weight:bold;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;background-color:#f8ff00;color:#333333;text-align:center;vertical-align:top">K=3</th><th style="font-family:Arial, sans-serif;font-size:14px;font-weight:bold;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;background-color:#f8ff00;color:#333333;text-align:center;vertical-align:top">k=5</th><th style="font-family:Arial, sans-serif;font-size:14px;font-weight:bold;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;background-color:#f8ff00;color:#333333;text-align:center;vertical-align:top">k=10</th></tr><tr><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#ffcb2f;text-align:center;vertical-align:top">Tiempo</td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">64.4</td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">12.4</td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">280.2</td></tr><tr><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#ffcb2f;text-align:center;vertical-align:top">CCR</td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">91.333333</td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">91</td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">91.333333</td></tr><tr><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#ffcb2f;text-align:center;vertical-align:top">C</td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">2</td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">8</td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">2</td></tr><tr><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;background-color:#ffcb2f;text-align:center;vertical-align:top"><span style="font-weight:bold">GAMMA</span></td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">0.0006905339660024879</td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">0.0001451668841556056</td><td style="font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:black;font-weight:bold;background-color:#fffc9e;text-align:center;vertical-align:top">0.006905339660024879</td></tr></table>
#
# Como se observa en la tabla anterior, el tiempo computacional se ha disparado cuanto mayor es el valor de **K** y el **CCR** no ha variado nada.

# %% [markdown]
# <img src="./img/e_preg14.png" />

# %%
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV
from sklearn.svm import SVC
import time
tuned_parameters = [{
                    'kernel': ['linear'],
                     'C': [0.01,0.1,1,10,100,1000]
                    }]

optimo = GridSearchCV(estimator=svm.SVC(),param_grid=tuned_parameters, n_jobs=-1, cv=5)
time_start = time.perf_counter()
data_train = pd.read_csv('./BasesDatos/csv/train_spam.csv',header=None)
data_test = pd.read_csv('./BasesDatos/csv/test_spam.csv',header=None)

train_inputs = data_train.iloc[:,:-1].values
train_outputs = data_train.iloc[:,-1].values

test_inputs = data_test.iloc[:,:-1].values
test_outputs = data_test.iloc[:,-1].values

optimo.fit(train_inputs, train_outputs)
Y_pred = optimo.predict(test_inputs)
time_elapsed = (time.perf_counter() - time_start)
print("%5.1f segundos" % (time_elapsed))
print('Valor de score: '+str(accuracy_score(test_outputs, Y_pred)))
print('Valores optimos: '+str(optimo.best_params_))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-400df5a29423> in <module>
#      23
#      24 optimo.fit(train_inputs, train_outputs)
# ---> 25 Y_pred = optimo.predict(test_inputs)
#      26 time_elapsed = (time.perf_counter() - time_start)
#      27 print("%5.1f segundos" % (time_elapsed))
#
# /usr/local/lib/python3.7/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     114
#     115         # lambda, but not partial, allows help() to work with update_wrapper
# --> 116         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     117         # update the docstring of the returned function
#     118         update_wrapper(out, self.fn)
#
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py in predict(self, X)
#     455         """
#     456         self._check_is_fitted('predict')
# ...

# %% [markdown]
# ###  Respuesta [14]:
#
# El método de **GridSearchCV** ha sacado que el mejor parametro **C=0.1** dando un **CCR=0.989**

# %% [markdown]
# <img src="./img/e_preg15.png" />

# %%
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.svm import SVC
import time

time_start = time.perf_counter()
data_train = pd.read_csv('./BasesDatos/csv/train_spam.csv', header=None)
data_test = pd.read_csv('./BasesDatos/csv/test_spam.csv', header=None)

train_inputs = data_train.iloc[:, :-1].values
train_outputs = data_train.iloc[:, -1].values

test_inputs = data_test.iloc[:, :-1].values
test_outputs = data_test.iloc[:, -1].values

optimo = svm.SVC(kernel='linear', C=0.1)
optimo.fit(train_inputs, train_outputs)
Y_pred = optimo.predict(test_inputs)
time_elapsed = (time.perf_counter() - time_start)

print("%5.1f segundos" % (time_elapsed))

print('Valor de score: ' + str(accuracy_score(test_outputs, Y_pred)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-167b68165aad> in <module>
#      18 optimo = svm.SVC(kernel='linear', C=0.1)
#      19 optimo.fit(train_inputs, train_outputs)
# ---> 20 Y_pred = optimo.predict(test_inputs)
#      21 time_elapsed = (time.perf_counter() - time_start)
#      22
#
# /usr/local/lib/python3.7/site-packages/sklearn/svm/base.py in predict(self, X)
#     572             Class labels for samples in X.
#     573         """
# --> 574         y = super().predict(X)
#     575         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     576
#
# /usr/local/lib/python3.7/site-packages/sklearn/svm/base.py in predict(self, X)
#     320         y_pred : array, shape (n_samples,)
#     321         """
# --> 322         X = self._validate_for_predict(X)
# ...
